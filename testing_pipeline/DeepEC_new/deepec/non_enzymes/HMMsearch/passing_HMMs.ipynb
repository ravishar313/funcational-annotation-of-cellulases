# %%
import pandas as pd
import os
import re

# %%
GH_families= ['GH1','GH2','GH5','GH10','GH26','GH30','GH39','GH51','GH148','GH6','GH3','GH44','GH13','GH124','GH116','GH48','GH8','GH9','GH45','GH16','GH7','GH12','GH131']

# %%
#getting all the file names
import glob
hmm_files=glob.glob('./HMMs/*.hmm')
fasta_files=glob.glob('all*.fasta')

# %%
fasta_files
# Out:
# ['all_non_enzyme_40.fasta']

# %%
hmm_files.sort()
hmm_files
# Out:
# ['./HMMs/GH10_80_no_outliers.hmm',
#  './HMMs/GH116_80_no_outliers.hmm',
#  './HMMs/GH12_80_no_outliers.hmm',
#  './HMMs/GH131_80_no_outliers.hmm',
#  './HMMs/GH13_80_no_outliers.hmm',
#  './HMMs/GH148_80_no_outliers.hmm',
#  './HMMs/GH16_80_no_outliers.hmm',
#  './HMMs/GH1_80_no_outliers.hmm',
#  './HMMs/GH26_80_no_outliers.hmm',
#  './HMMs/GH2_80_no_outliers.hmm',
#  './HMMs/GH30_80_no_outliers.hmm',
#  './HMMs/GH39_80_no_outliers.hmm',
#  './HMMs/GH3_80_no_outliers.hmm',
#  './HMMs/GH44_80_no_outliers.hmm',
#  './HMMs/GH45_80_no_outliers.hmm',
#  './HMMs/GH48_80_no_outliers.hmm',
#  './HMMs/GH51_80_no_outliers.hmm',
#  './HMMs/GH5_80_no_outliers.hmm',
#  './HMMs/GH6_60_no_outliers.hmm',
#  './HMMs/GH7_60_no_outliers.hmm',
#  './HMMs/GH8_80_no_outliers.hmm',
#  './HMMs/GH9_80_no_outliers.hmm']

# %%
#setting threshold values
threshold_df=pd.read_csv('thresholds.csv')
thresholds=threshold_df['Bit-score threshold'].to_list()
threshold_dic= dict(zip(hmm_files, thresholds))
threshold_dic
# Out:
# {'./HMMs/GH10_80_no_outliers.hmm': 200,
#  './HMMs/GH116_80_no_outliers.hmm': 34,
#  './HMMs/GH12_80_no_outliers.hmm': 120,
#  './HMMs/GH131_80_no_outliers.hmm': 387,
#  './HMMs/GH13_80_no_outliers.hmm': 91,
#  './HMMs/GH148_80_no_outliers.hmm': 44,
#  './HMMs/GH16_80_no_outliers.hmm': 88,
#  './HMMs/GH1_80_no_outliers.hmm': 352,
#  './HMMs/GH26_80_no_outliers.hmm': 90,
#  './HMMs/GH2_80_no_outliers.hmm': 215,
#  './HMMs/GH30_80_no_outliers.hmm': 269,
#  './HMMs/GH39_80_no_outliers.hmm': 226,
#  './HMMs/GH3_80_no_outliers.hmm': 251,
#  './HMMs/GH44_80_no_outliers.hmm': 339,
#  './HMMs/GH45_80_no_outliers.hmm': 108,
#  './HMMs/GH48_80_no_outliers.hmm': 869,
#  './HMMs/GH51_80_no_outliers.hmm': 342,
#  './HMMs/GH5_80_no_outliers.hmm': 55,
#  './HMMs/GH6_60_no_outliers.hmm': 363,
#  './HMMs/GH7_60_no_outliers.hmm': 436,
#  './HMMs/GH8_80_no_outliers.hmm': 241,
#  './HMMs/GH9_80_no_outliers.hmm': 391}

# %%
df = pd.DataFrame(index=GH_families, columns=GH_families.append('nonGHoI'))

# %%
#all_sequences vs all hmms
ids=[]
for i,hmm in enumerate(hmm_files): 
    for j,fasta_file in enumerate(fasta_files):
        eval_file=hmm.split('/')[2].split('.')[0]+'_vs_'+fasta_file.split('.')[0]+'.txt'
        threshold=str(threshold_dic[hmm])
        cmd_search='hmmsearch --noali --domT ' +threshold +' --domtblout ' + eval_file+' '+ hmm+' '+fasta_file
        os.system(cmd_search)
        
        use, no_use=[],[]
        with open(eval_file,'r',encoding='utf-8') as otp:
            for ii in otp:
                if ii.startswith('#'):
                    #print(no_use)
                    no_use.append(ii)
                else:
                    #print(use)
                    use.append(ii) 
        xx=len(use)
        if xx>0:
            new_data=[]
            for i in use:
                j=re.split('\s+',i.strip())
                new_data.append(j)
            df2=pd.DataFrame(new_data)
            df3=df2[[0,13,15,16,17,18,22]]
            df3.columns=['ID','Score','hmm_start','hmm_end','ali_start','ali_end','description']
            x=df3['description'].tolist()
            y=df3['ID'].tolist()
            filename4=eval_file.split('.')[0]+'_raw.csv'
            df3.to_csv(filename4)
            IDs=[]
            for i in range(len(x)):
                if x[i].startswith('-'):
                    z=y[i]
                    IDs.append(z)
                else:
                    z=y[i]+x[i]
                    IDs.append(z)
            df3['IDs']=IDs
            df3=df3.drop(['ID','description'], axis=1)
            df3.Score = df3.Score.astype(float)
            df3=df3.sort_values(by=['Score'], ascending=False)
            
            #score=df3['Score'].to_list()
            data=df3['IDs'].to_list()
            #num_of_hits=len(set(data))
            #max_score=max(score)
            #min_score=min(score)
            
            ids=ids+data

ids_final=list(set(ids))
filename='HMMs_2nd_pass.txt'
with open(filename,'w') as f:
    for i in ids_final:
        f.write(i+'\n')
# Out:
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH10_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH10_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 200
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH10_80_no_outliers  [M=487]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#   ------ inclusion threshold ------
#       0.052   13.8   0.0        3.2    7.9   0.0    3.1  0  Q5UPD5@YL059_MIMIV
#        0.15   12.3   0.0       0.23   11.7   0.0    1.2  0  P15718@POLB_MAIZE
#        0.35   11.1   0.0       0.35   11.1   0.0    1.0  0  P23554@YXYB_CALSA
#
#
# Domain annotation for each sequence:
# >> Q5UPD5@YL059_MIMIV
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P15718@POLB_MAIZE
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P23554@YXYB_CALSA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (487 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      3612  (0.0722892); expected 999.3 (0.02)
# Passed bias filter:                     1412  (0.0282592); expected 999.3 (0.02)
# Passed Vit filter:                       160  (0.00320218); expected 50.0 (0.001)
# Passed Fwd filter:                         3  (6.00408e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               3  [number of targets reported over threshold]
# # CPU time: 0.34u 0.01s 00:00:00.35 Elapsed: 00:00:00.16
# # Mc/sec: 50897.41
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH116_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH116_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 34
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH116_80_no_outliers  [M=985]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (985 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1671  (0.0334427); expected 999.3 (0.02)
# Passed bias filter:                      670  (0.0134091); expected 999.3 (0.02)
# Passed Vit filter:                        41  (0.000820558); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.50u 0.00s 00:00:00.50 Elapsed: 00:00:00.23
# # Mc/sec: 71282.78
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH12_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH12_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 120
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH12_80_no_outliers  [M=370]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (370 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2494  (0.0499139); expected 999.3 (0.02)
# Passed bias filter:                      965  (0.0193131); expected 999.3 (0.02)
# Passed Vit filter:                        63  (0.00126086); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.23u 0.00s 00:00:00.23 Elapsed: 00:00:00.09
# # Mc/sec: 62539.97
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH131_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH131_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 387
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH131_80_no_outliers  [M=363]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#     1.9e-07   31.9  30.4      0.032   14.7   1.3    4.0  0  P50272@PSBP_PORPU
#      0.0018   18.8   4.4     0.0018   18.8   4.4    3.9  0  Q9P7F1@YKK5_SCHPO
#   ------ inclusion threshold ------
#         3.7    7.9  13.5        4.4    7.7  13.5    1.2  0  P16795@GN_HCMVA
#         7.1    7.0   7.5         11    6.4   7.5    1.2  0  Q9QZW9@MNX1_MOUSE
#
#
# Domain annotation for each sequence:
# >> P50272@PSBP_PORPU
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q9P7F1@YKK5_SCHPO
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P16795@GN_HCMVA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q9QZW9@MNX1_MOUSE
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (363 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      3354  (0.0671256); expected 999.3 (0.02)
# Passed bias filter:                     1484  (0.0297002); expected 999.3 (0.02)
# Passed Vit filter:                       268  (0.00536365); expected 50.0 (0.001)
# Passed Fwd filter:                        72  (0.00144098); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               4  [number of targets reported over threshold]
# # CPU time: 0.66u 0.01s 00:00:00.67 Elapsed: 00:00:00.32
# # Mc/sec: 18615.61
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH13_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH13_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 91
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH13_80_no_outliers  [M=557]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#     4.7e-84  284.6   2.0      6e-84  284.3   2.0    1.0  1  Q91WV7@SLC31_MOUSE
#       2e-30  107.6   0.4    2.5e-30  107.2   0.4    1.1  1  P76616@YGAQ_ECOLI
#   ------ inclusion threshold ------
#        0.28   11.3   0.0       0.42   10.8   0.0    1.2  0  Q58850@Y1455_METJA
#         2.8    8.1   5.7        3.9    7.6   5.7    1.3  0  Q5HZW7@PLET1_RAT
#
#
# Domain annotation for each sequence:
# >> Q91WV7@SLC31_MOUSE
#    #    score  bias  c-Evalue  i-Evalue hmmfrom  hmm to    alifrom  ali to    envfrom  env to     acc
#  ---   ------ ----- --------- --------- ------- -------    ------- -------    ------- -------    ----
#    1 !  284.3   2.0   4.8e-88     6e-84      39     475 ..     106     653 ..      55     679 .. 0.80
#
# >> P76616@YGAQ_ECOLI
#    #    score  bias  c-Evalue  i-Evalue hmmfrom  hmm to    alifrom  ali to    envfrom  env to     acc
#  ---   ------ ----- --------- --------- ------- -------    ------- -------    ------- -------    ----
#    1 !  107.2   0.4     2e-34   2.5e-30      67     470 ..     217     738 ..      73     747 .. 0.71
#
# >> Q58850@Y1455_METJA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q5HZW7@PLET1_RAT
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (557 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2304  (0.0461114); expected 999.3 (0.02)
# Passed bias filter:                     1190  (0.0238162); expected 999.3 (0.02)
# Passed Vit filter:                       104  (0.00208142); expected 50.0 (0.001)
# Passed Fwd filter:                         4  (8.00544e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               4  [number of targets reported over threshold]
# # CPU time: 0.36u 0.00s 00:00:00.36 Elapsed: 00:00:00.16
# # Mc/sec: 57607.42
# //
# [ok]
# /tmp/ipykernel_113980/2450660144.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['IDs']=IDs
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH148_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH148_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 44
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH148_80_no_outliers  [M=1146]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (1146 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1167  (0.0233559); expected 999.3 (0.02)
# Passed bias filter:                      914  (0.0182924); expected 999.3 (0.02)
# Passed Vit filter:                        64  (0.00128087); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.61u 0.00s 00:00:00.61 Elapsed: 00:00:00.28
# # Mc/sec: 67307.74
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH16_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH16_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 88
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH16_80_no_outliers  [M=406]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#     3.9e-28  100.3   4.1      5e-28   99.9   4.1    1.2  1  Q9NHA8@BGBP3_DROME
#     4.2e-23   83.7   0.0    1.5e-22   81.9   0.0    1.8  0  Q9NHB0@GNBP1_DROME
#     1.1e-22   82.3   0.4    1.6e-22   81.8   0.4    1.2  0  Q9VVR4@BGBP2_DROME
#
#
# Domain annotation for each sequence:
# >> Q9NHA8@BGBP3_DROME
#    #    score  bias  c-Evalue  i-Evalue hmmfrom  hmm to    alifrom  ali to    envfrom  env to     acc
#  ---   ------ ----- --------- --------- ------- -------    ------- -------    ------- -------    ----
#    1 !   99.9   4.1     3e-32     5e-28      82     289 ..     174     490 .]      69     490 .] 0.76
#
# >> Q9NHB0@GNBP1_DROME
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q9VVR4@BGBP2_DROME
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (406 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      5357  (0.107213); expected 999.3 (0.02)
# Passed bias filter:                     2257  (0.0451707); expected 999.3 (0.02)
# Passed Vit filter:                       338  (0.0067646); expected 50.0 (0.001)
# Passed Fwd filter:                         4  (8.00544e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               3  [number of targets reported over threshold]
# # CPU time: 0.39u 0.01s 00:00:00.40 Elapsed: 00:00:00.18
# # Mc/sec: 37872.08
# //
# [ok]
# /tmp/ipykernel_113980/2450660144.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['IDs']=IDs
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH1_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH1_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 352
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH1_80_no_outliers  [M=502]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#   ------ inclusion threshold ------
#       0.072   12.9   0.2       0.08   12.7   0.2    1.1  0  Q5UPB2@YL038_MIMIV
#
#
# Domain annotation for each sequence:
# >> Q5UPB2@YL038_MIMIV
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (502 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1673  (0.0334828); expected 999.3 (0.02)
# Passed bias filter:                      880  (0.017612); expected 999.3 (0.02)
# Passed Vit filter:                        73  (0.00146099); expected 50.0 (0.001)
# Passed Fwd filter:                         1  (2.00136e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               1  [number of targets reported over threshold]
# # CPU time: 0.30u 0.00s 00:00:00.30 Elapsed: 00:00:00.13
# # Mc/sec: 64435.51
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH26_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH26_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 90
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH26_80_no_outliers  [M=448]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#   ------ inclusion threshold ------
#       0.038   14.4   0.0         34    4.7   0.0    3.9  0  P18714@ZG20_XENLA
#       0.097   13.1   0.0       0.12   12.8   0.0    1.1  0  Q54XX1@SRPRB_DICDI
#        0.19   12.1   0.5       0.27   11.6   0.5    1.2  0  P47614@Y374_MYCGE
#
#
# Domain annotation for each sequence:
# >> P18714@ZG20_XENLA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q54XX1@SRPRB_DICDI
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P47614@Y374_MYCGE
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (448 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2398  (0.0479926); expected 999.3 (0.02)
# Passed bias filter:                     1206  (0.0241364); expected 999.3 (0.02)
# Passed Vit filter:                       114  (0.00228155); expected 50.0 (0.001)
# Passed Fwd filter:                         3  (6.00408e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               3  [number of targets reported over threshold]
# # CPU time: 0.29u 0.00s 00:00:00.28 Elapsed: 00:00:00.12
# # Mc/sec: 59062.48
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH2_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH2_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 215
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH2_80_no_outliers  [M=833]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence          Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------          -----------
#       7e-11   42.6   0.1    8.8e-11   42.3   0.1    1.1  0  P56092@EPD1_CANMA
#   ------ inclusion threshold ------
#        0.12   12.1   0.3       0.21   11.3   0.3    1.3  0  P54232@VEF_GVHA
#
#
# Domain annotation for each sequence:
# >> P56092@EPD1_CANMA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P54232@VEF_GVHA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (833 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1898  (0.0379858); expected 999.3 (0.02)
# Passed bias filter:                      941  (0.0188328); expected 999.3 (0.02)
# Passed Vit filter:                        78  (0.00156106); expected 50.0 (0.001)
# Passed Fwd filter:                         2  (4.00272e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               2  [number of targets reported over threshold]
# # CPU time: 0.47u 0.00s 00:00:00.47 Elapsed: 00:00:00.21
# # Mc/sec: 64132.22
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH30_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH30_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 269
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH30_80_no_outliers  [M=591]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (591 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2262  (0.0452708); expected 999.3 (0.02)
# Passed bias filter:                     1106  (0.0221351); expected 999.3 (0.02)
# Passed Vit filter:                        74  (0.00148101); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.34u 0.00s 00:00:00.34 Elapsed: 00:00:00.15
# # Mc/sec: 65586.17
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH39_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH39_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 226
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH39_80_no_outliers  [M=526]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (526 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1746  (0.0349438); expected 999.3 (0.02)
# Passed bias filter:                      796  (0.0159308); expected 999.3 (0.02)
# Passed Vit filter:                        56  (0.00112076); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.28u 0.01s 00:00:00.29 Elapsed: 00:00:00.12
# # Mc/sec: 69073.08
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH3_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH3_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 251
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH3_80_no_outliers  [M=988]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#     0.00078   19.3   0.2       0.62    9.6   0.1    2.4  0  Q58956@Y1561_METJA
#   ------ inclusion threshold ------
#       0.051   13.2   0.3      0.049   13.3   0.3    1.1  0  O31622@COTO_BACSU
#       0.082   12.6   0.0       0.17   11.5   0.0    1.3  0  P01014@OVALY_CHICK
#        0.14   11.7   0.4       0.17   11.5   0.4    1.0  0  O29043@Y1225_ARCFU
#        0.21   11.2   0.9       0.21   11.2   0.9    1.1  0  Q8IE51@Y13P1_PLAF7
#
#
# Domain annotation for each sequence:
# >> Q58956@Y1561_METJA
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> O31622@COTO_BACSU
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P01014@OVALY_CHICK
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> O29043@Y1225_ARCFU
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q8IE51@Y13P1_PLAF7
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (988 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1988  (0.0397871); expected 999.3 (0.02)
# Passed bias filter:                     1058  (0.0211744); expected 999.3 (0.02)
# Passed Vit filter:                        85  (0.00170116); expected 50.0 (0.001)
# Passed Fwd filter:                         5  (0.000100068); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               5  [number of targets reported over threshold]
# # CPU time: 0.58u 0.00s 00:00:00.57 Elapsed: 00:00:00.26
# # Mc/sec: 61830.15
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH44_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH44_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 339
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH44_80_no_outliers  [M=767]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (767 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2026  (0.0405476); expected 999.3 (0.02)
# Passed bias filter:                      734  (0.01469); expected 999.3 (0.02)
# Passed Vit filter:                        48  (0.000960653); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.41u 0.00s 00:00:00.41 Elapsed: 00:00:00.18
# # Mc/sec: 70044.88
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH45_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH45_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 108
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH45_80_no_outliers  [M=262]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#      0.0012   20.0   0.0     0.0022   19.1   0.0    1.4  0  Q2QP13@EXP26_ORYSJ
#   ------ inclusion threshold ------
#       0.014   16.5   0.7        2.1    9.4   0.2    2.3  0  Q9FL76@EXP24_ARATH
#       0.059   14.4   0.5       0.11   13.6   0.5    1.4  0  Q54C78@EXPL9_DICDI
#
#
# Domain annotation for each sequence:
# >> Q2QP13@EXP26_ORYSJ
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q9FL76@EXP24_ARATH
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q54C78@EXPL9_DICDI
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (262 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2088  (0.0417884); expected 999.3 (0.02)
# Passed bias filter:                      834  (0.0166914); expected 999.3 (0.02)
# Passed Vit filter:                        58  (0.00116079); expected 50.0 (0.001)
# Passed Fwd filter:                         3  (6.00408e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               3  [number of targets reported over threshold]
# # CPU time: 0.18u 0.00s 00:00:00.18 Elapsed: 00:00:00.07
# # Mc/sec: 62440.40
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH48_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH48_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 869
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH48_80_no_outliers  [M=863]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#     2.7e-25   90.3   1.1    3.4e-25   90.0   1.1    1.1  0  A3DCG3@RSGI4_ACET2
#     5.1e-16   59.6   0.0    7.1e-16   59.1   0.0    1.2  0  A3DC27@RSGI2_ACET2
#     1.2e-13   51.8   0.0    1.4e-13   51.5   0.0    1.2  0  A3DBH1@RSGI1_ACET2
#
#
# Domain annotation for each sequence:
# >> A3DCG3@RSGI4_ACET2
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> A3DC27@RSGI2_ACET2
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> A3DBH1@RSGI1_ACET2
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (863 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2360  (0.0472321); expected 999.3 (0.02)
# Passed bias filter:                      979  (0.0195933); expected 999.3 (0.02)
# Passed Vit filter:                        99  (0.00198135); expected 50.0 (0.001)
# Passed Fwd filter:                         4  (8.00544e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               3  [number of targets reported over threshold]
# # CPU time: 0.51u 0.01s 00:00:00.52 Elapsed: 00:00:00.24
# # Mc/sec: 59757.28
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH51_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH51_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 342
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH51_80_no_outliers  [M=533]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (533 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2141  (0.0428491); expected 999.3 (0.02)
# Passed bias filter:                      959  (0.0191931); expected 999.3 (0.02)
# Passed Vit filter:                        87  (0.00174118); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.32u 0.00s 00:00:00.32 Elapsed: 00:00:00.14
# # Mc/sec: 62566.13
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH5_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH5_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 55
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH5_80_no_outliers  [M=410]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#     3.7e-15   57.4   0.4    4.4e-15   57.2   0.4    1.1  1  P56092@EPD1_CANMA
#       2e-13   51.7   0.1    2.7e-13   51.3   0.1    1.2  0  O13692@GAS5_SCHPO
#   ------ inclusion threshold ------
#        0.12   13.0   0.6         16    5.9   0.0    2.1  0  P18377@PG042_VACCW
#
#
# Domain annotation for each sequence:
# >> P56092@EPD1_CANMA
#    #    score  bias  c-Evalue  i-Evalue hmmfrom  hmm to    alifrom  ali to    envfrom  env to     acc
#  ---   ------ ----- --------- --------- ------- -------    ------- -------    ------- -------    ----
#    1 !   57.2   0.4   2.6e-19   4.4e-15      32     346 ..      11     453 ..       1     542 [. 0.51
#
# >> O13692@GAS5_SCHPO
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P18377@PG042_VACCW
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (410 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      3542  (0.0708882); expected 999.3 (0.02)
# Passed bias filter:                     2240  (0.0448305); expected 999.3 (0.02)
# Passed Vit filter:                       271  (0.00542369); expected 50.0 (0.001)
# Passed Fwd filter:                         4  (8.00544e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               3  [number of targets reported over threshold]
# # CPU time: 0.30u 0.02s 00:00:00.32 Elapsed: 00:00:00.14
# # Mc/sec: 48821.20
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH6_60_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH6_60_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 363
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH6_60_no_outliers  [M=442]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (442 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2289  (0.0458112); expected 999.3 (0.02)
# Passed bias filter:                      888  (0.0177721); expected 999.3 (0.02)
# Passed Vit filter:                        73  (0.00146099); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.26u 0.00s 00:00:00.26 Elapsed: 00:00:00.11
# # Mc/sec: 66201.23
# //
# [ok]
# /tmp/ipykernel_113980/2450660144.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['IDs']=IDs
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH7_60_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH7_60_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 436
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH7_60_no_outliers  [M=431]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#   ------ inclusion threshold ------
#        0.13   12.4   3.5       0.13   12.3   3.5    1.0  0  Q2V3Y8@DEF45_ARATH
#
#
# Domain annotation for each sequence:
# >> Q2V3Y8@DEF45_ARATH
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (431 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1898  (0.0379858); expected 999.3 (0.02)
# Passed bias filter:                      785  (0.0157107); expected 999.3 (0.02)
# Passed Vit filter:                        67  (0.00134091); expected 50.0 (0.001)
# Passed Fwd filter:                         1  (2.00136e-05); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               1  [number of targets reported over threshold]
# # CPU time: 0.24u 0.00s 00:00:00.24 Elapsed: 00:00:00.10
# # Mc/sec: 71212.08
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH8_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH8_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 241
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH8_80_no_outliers  [M=394]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence Description
#     ------- ------ -----    ------- ------ -----   ---- --  -------- -----------
#
#    [No hits detected that satisfy reporting thresholds]
#
#
# Domain annotation for each sequence:
#
#    [No targets detected that satisfy reporting thresholds]
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (394 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      1964  (0.0393067); expected 999.3 (0.02)
# Passed bias filter:                      990  (0.0198135); expected 999.3 (0.02)
# Passed Vit filter:                        65  (0.00130088); expected 50.0 (0.001)
# Passed Fwd filter:                         0  (0); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               0  [number of targets reported over threshold]
# # CPU time: 0.23u 0.00s 00:00:00.23 Elapsed: 00:00:00.10
# # Mc/sec: 65203.88
# //
# [ok]
# # hmmsearch :: search profile(s) against a sequence database
# # HMMER 3.3 (Nov 2019); http://hmmer.org/
# # Copyright (C) 2019 Howard Hughes Medical Institute.
# # Freely distributed under the BSD open source license.
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# # query HMM file:                  ./HMMs/GH9_80_no_outliers.hmm
# # target sequence database:        all_non_enzyme_40.fasta
# # per-dom hits tabular output:     GH9_80_no_outliers_vs_all_non_enzyme_40.txt
# # show alignments in output:       no
# # domain reporting threshold:      score >= 391
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#
# Query:       GH9_80_no_outliers  [M=684]
# Scores for complete sequences (score includes all domains):
#    --- full sequence ---   --- best 1 domain ---    -#dom-
#     E-value  score  bias    E-value  score  bias    exp  N  Sequence           Description
#     ------- ------ -----    ------- ------ -----   ---- --  --------           -----------
#      0.0031   17.5   0.5      0.011   15.7   0.0    1.9  0  P37512@YYAL_BACSU
#   ------ inclusion threshold ------
#        0.27   11.1   0.4       0.28   11.0   0.4    1.2  0  Q86JE1@Y2130_DICDI
#        0.56   10.0   0.0       0.79    9.5   0.0    1.2  0  P76639@YGEH_ECOLI
#        0.57   10.0   0.5        4.3    7.1   0.0    2.3  0  Q9NS86@LANC2_HUMAN
#         4.3    7.1   5.4        5.4    6.8   5.4    1.1  0  P31316@GSX2_MOUSE
#
#
# Domain annotation for each sequence:
# >> P37512@YYAL_BACSU
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q86JE1@Y2130_DICDI
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P76639@YGEH_ECOLI
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> Q9NS86@LANC2_HUMAN
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
# >> P31316@GSX2_MOUSE
#    [No individual domains that satisfy reporting thresholds (although complete target did)]
#
#
#
# Internal pipeline statistics summary:
# -------------------------------------
# Query model(s):                            1  (684 nodes)
# Target sequences:                      49966  (16844371 residues searched)
# Passed MSV filter:                      2447  (0.0489733); expected 999.3 (0.02)
# Passed bias filter:                     1073  (0.0214746); expected 999.3 (0.02)
# Passed Vit filter:                       112  (0.00224152); expected 50.0 (0.001)
# Passed Fwd filter:                         5  (0.000100068); expected 0.5 (1e-05)
# Initial search space (Z):              49966  [actual number of targets]
# Domain search space  (domZ):               5  [number of targets reported over threshold]
# # CPU time: 0.44u 0.00s 00:00:00.44 Elapsed: 00:00:00.20
# # Mc/sec: 56682.40
# //
# [ok]
