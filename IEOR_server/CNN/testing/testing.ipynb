# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json
import numpy as np
import pandas as pd
# Out:
# 2023-04-22 18:07:50.548713: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-22 18:07:50.608415: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-22 18:07:52.186659: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
with open('model_07.json', 'r') as f:
    model_json = f.read()
model = model_from_json(model_json)

# %%
model.load_weights('model_07.h5')

# %%
X_test=np.load('X_non_enzyme.npy')
y_test=np.load('y_non_enzyme.npy')

# %%
yy_df=pd.DataFrame(y_test)
yy=yy_df[1].to_list()
yy.count(0)
# Out:
# 49941

# %%
model1=load_model('model_09.h5')

# %%
y_predicted = model1.predict(X_test)
# Out:
# 1561/1561 [==============================] - 26s 16ms/step

# %%
y_predicted_df=pd.DataFrame(y_predicted)
ff=y_predicted_df[1].to_list()
ff
# Out:
# [0.09067662805318832,
#  0.0026676736306399107,
#  0.11020752042531967,
#  0.08836998790502548,
#  0.2321857213973999,
#  0.2686957120895386,
#  0.10336170345544815,
#  0.009153715334832668,
#  0.02108090929687023,
#  0.00019666999287437648,
#  0.00024804769782349467,
#  0.004114637617021799,
#  0.01965564861893654,
#  0.009388873353600502,
#  0.1851872056722641,
#  0.032882094383239746,
#  0.002110470086336136,
#  0.005918998271226883,
#  0.0867270976305008,
#  0.0043120854534208775,
#  0.03899083659052849,
#  0.05565653368830681,
#  0.0008569987257942557,
#  0.003307558596134186,
#  0.013812821358442307,
#  0.020309757441282272,
#  0.02722959779202938,
#  3.569289037841372e-05,
#  0.0032411059364676476,
#  0.00025016433210112154,
#  0.6168252825737,
#  0.03278264030814171,
#  0.024338318035006523,
#  0.3297940790653229,
#  0.18109183013439178,
#  0.021069955080747604,
#  0.03464164212346077,
#  0.9436047673225403,
#  0.06012804061174393,
#  0.039850134402513504,
# ...

# %%
len(y_test)
# Out:
# 49941

# %%
pred_list=[]
for i in ff:
    if i >0.5:
        pred_list.append(1)
    else:
        pred_list.append(0)

# %%
prediction=pd.DataFrame(pred_list)
prediction
# Out:
#        0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 49936  0
# 49937  0
# 49938  0
# 49939  0
# 49940  0
#
# [49941 rows x 1 columns]

# %%
pred=prediction[0].to_list()
pred.count(0)
# Out:
# 46152

# %%
from sklearn.metrics import precision_score, recall_score

# %%
precision = precision_score(yy_df[1], prediction)
recall = recall_score(yy_df[1], prediction)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
precision
# Out:
# 0.0

# %%
recall
# Out:
# 0.0

# %%
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp =confusion_matrix(yy_df[1], prediction).ravel()

# %%
tp
# Out:
# 0

# %%
model1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
loss, accuracy = model1.evaluate(X_test, y_test, verbose=0)

# %%
loss
# Out:
# 1.0418117046356201

# %%
accuracy
# Out:
# 0.7801688313484192
